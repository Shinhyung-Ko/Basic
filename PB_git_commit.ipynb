# %%
print('hello world')
# Out:
# hello world

# %%
cd /content/drive/MyDrive/Colab Notebooks/commit/Basic
# Out:
# /content/drive/MyDrive/Colab Notebooks/commit/Basic

# %%
#git 로그인
# !git config --global user.email 'rhtlsgud10@gmail.com'
# !git config --global user.name 'Shinhyung-Ko'

# %%
# !git add --all

# %%
# !git commit -m 'python basic 옮기기 완료'
# !git push
# Out:
# [main 934542d] python basic 옮기기 완료
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite PB_git_commit.ipynb (66%)
#  create mode 100644 numpy_pandas_matplotlib.ipynb
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 83.35 KiB | 4.90 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Shinhyung-Ko/Basic.git
#    3883fdb..934542d  main -> main
